# %% [markdown]
# <a href="https://colab.research.google.com/github/Eserhimas/Basics/blob/main/Sci_kit_Learn_TimeSeriesSplit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import TimeSeriesSplit

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generating a synthetic time series dataset
np.random.seed(0)
data = np.random.randn(100)  # 100 data points
time = pd.date_range(start='2020-01-01', periods=len(data), freq='D')
series = pd.Series(data, index=time)

# %%
tscv = TimeSeriesSplit(n_splits=5)

series
# Out:
# 2020-01-01    1.764052
# 2020-01-02    0.400157
# 2020-01-03    0.978738
# 2020-01-04    2.240893
# 2020-01-05    1.867558
#                 ...
# 2020-04-05    0.706573
# 2020-04-06    0.010500
# 2020-04-07    1.785870
# 2020-04-08    0.126912
# 2020-04-09    0.401989
# Freq: D, Length: 100, dtype: float64

# %%
for train_index, test_index in tscv.split(series):
    train, test = series.iloc[train_index], series.iloc[test_index]
    plt.figure(figsize=(10, 2))

    plt.plot(train.index, train, color='blue')
    plt.plot(test.index, test, color='orange')
    plt.title('Train (blue) and Test (orange) Split')
    plt.show()
